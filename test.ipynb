# %%
from movie import SWF
from export import SVGExporter

# %%
f = open("123.swf", "rb")

# %%
swf = SWF(f)

# %%
print(swf)
# Out:
# [SWF]
#    [SWFHeader]
#        Version: 9
#        FileLength: 152042
#        FrameSize: [xmin: 0 xmax: 970 ymin: 0 ymax: 570]
#        FrameRate: 24
#        FrameCount: 140
# [69:FileAttributes] useDirectBlit: 0, useGPU: 0, hasMetadata: 1, actionscript3: 1, useNetwork: 0
# ...

# %%
# export!
svg = swf.export()

# save the SVG
open('path/to/svg', 'wb').write(svg.read())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 2
#       1 # export!
# ----> 2 svg = swf.export()
#       4 # save the SVG
#       5 open('path/to/svg', 'wb').write(svg.read())
#
# File e:\Game_tools\SWF\movie.py:126, in SWF.export(self, exporter, force_stroke)
#     124 if len(self.tags) == 0:
#     125     raise Exception("This SWF doesn't contain any tags!")
# --> 126 return exporter.export(self, force_stroke)
#
# File e:\Game_tools\SWF\export.py:521, in SVGExporter.export(self, swf, force_stroke)
#     518 self.fontInfos = dict([(x.characterId,x) for x in swf.all_tags_of_type(TagDefineFontInfo)])
#     520 # GO!
# --> 521 super(SVGExporter, self).export(swf, force_stroke)
#     523 # Setup svg @width, @height and @viewBox
#     524 # and add the optional margin
#     525 self.bounds = SVGBounds(self.svg)
#
# ...
